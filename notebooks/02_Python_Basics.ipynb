# %% [markdown]
# # This notebooks covers Data Types, control flow, Loops, Functions,Indexing,Operators.

# %%
# The only way to learn all this is quickly skimming through the jargon and actully get your hand dirty with a simple project or solving some
# dsa questions as each of them have many differnt methods which you can't memorize unless you actully use it so try to get your hands dirty as 
# fast as possible

# %% [markdown]
# ## Starting with data types for the ease of understanding we will classify them in 7 differnt types.
#   ### 1. Numeric Types
#   ### 2. Boolean Type
#   ### 3. Sequence Types
#   ### 4. Mapping Type
#   ### 5. Set Types
#   ### 6. Binary Types
#   ### 7. None Type

# %% [markdown]
# # 1. Numeric Types
#
#   ## Used to store numbers.

# %%
# int

# Whole numbers (no decimal).

x = 10
type(x)
# Out:
# int

# %% [markdown]
# ### NOTE: tyep() used to check type of a variable

# %%
# float

## Decimal numbers.

y = 3.14
type(y)
# Out:
# float

# %%
# complex

## Numbers with real + imaginary parts.

z = 3 + 4j
type(z)
# Out:
# complex

# %% [markdown]
# # 2. Boolean Type
#
# ## Used for truth values.

# %%
# bool

a = True
b = False


# Internally:

True  == 1
False == 0
# Out:
# True

# %% [markdown]
# # 3. Sequence Types
#
# ## Ordered collections.

# %%
# str (String) – immutable
s = "hello"

# %% [markdown]
# # Indexing/Slicing

# %% [markdown]
# # s[start : stop : step]

# %%
s[1]
# Out:
# 'e'

# %%
s[:]
# Out:
# 'hello'

# %%
# we can use : multiple time to perform indexing better way at first it's just used to mention index if we write number both the sides
# of : then we have starting to end index value we want , and by writring ::x at the third position it is used for steps to jump 
# now in python negative indexing is also allowed 
s[::2]
# Out:
# 'hlo'

# %%
s[-1]
# Out:
# 'o'

# %%
s[:-2:2]
# Out:
# 'hl'

# %% [markdown]
# # The concept of indexing and slicing is same across all sequence types

# %%
# list – mutable 
# list is same as array in c++ except it's an object and it can store differnt data types at the same time it is dynamically (resizable)
# and it stores refrence to objects not actual values 
lst = [1, 2, 3]

lst2 = [True,"Hey",1,2,3]
lst2
type(lst2)
# Out:
# list

# %%
# tuple – immutable
# tuple are mostly like list but faster as value can't be changed in them also they are shallow immutable that means tuple itself
# can't change whom it is pointing to but the object itself may still be mutalbe
t = (1, 2, 3)
t
# Out:
# (1, 2, 3)

# %%
# range
r = range(5)

# %%
r
# Out:
# range(0, 5)

# %% [markdown]
# # 4. Mapping Type
#
# # Key → Value pairs.

# %%
# dict 
# here the key has to be of an immutable data type 
d = {"name": "Anant", "age": 21}

# %% [markdown]
# # 6. Binary Types
#
# # Used for raw binary data.

# %%
# bytes (immutable)
b = b"hello"

# %%
# bytearray (mutable)
ba = bytearray(b"hello")

# %%
# memoryview
mv = memoryview(b"hello")

# %% [markdown]
# # 7. None Type
# # Represents “nothing”.

# %%
# NoneType
x = None

# %%
print(x)
# Out:
# None

# %% [markdown]
# # Control Flow Statement

# %%
# this is the most important of any programming language 
# where you are mostly going to use if-else statement for/while loop and sometimes do-while loop 
# the most important rule to remember in python control flow is indentation 
# if-else example

x=10

if x<10:
    print("hi")
elif x%2==0:
    print("even")
else:
    print(x)
# Out:
# even

# %%
# how to take input from the user
x = input("enter number")
print(x)
# the important thing here is when we do type(x)
print(type(x))
# we can see it's an string not an integer becase by default input() converts any input type to string so to make it
# Out:
# enter number 10
# 10
# <class 'str'>
